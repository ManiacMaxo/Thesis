# %%
from tensorflow.keras.models import load_model
from os import listdir

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, Bidirectional
from tensorflow.keras.backend import clear_session

# %%
clear_session()
models = [
    Sequential([ # model_0
        LSTM(2, input_shape=(4, 1000), dropout=0.5, recurrent_dropout=0.5),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_1
        LSTM(1, input_shape=(4, 1000), dropout=0.5),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_2
        LSTM(1, input_shape=(4, 1000), dropout=0.3),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_3
        LSTM(1, input_shape=(4, 1000)),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_4
        Bidirectional(LSTM(1, dropout=0.3), input_shape=(4, 1000)),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_5
        Bidirectional(LSTM(1, dropout=0.5), input_shape=(4, 1000)),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ]),
    Sequential([ # model_6
        Bidirectional(LSTM(1), input_shape=(4, 1000)),
        Dense(4, activation='relu'),
        Dropout(0.5),
        Dense(1, activation='relu')
    ])
]
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU

# %%
for i, model in enumerate(models):
    model.summary()
    model.save(f'../model_saves/eval_models/model_{i}.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm (LSTM)                  (None, 2)                 8024
# _________________________________________________________________
# dense (Dense)                (None, 4)                 12
# _________________________________________________________________
# dropout (Dropout)            (None, 4)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 5
# ...
# Total params: 8,041
# Trainable params: 8,041
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# lstm_1 (LSTM)                (None, 1)                 4008
# ...
